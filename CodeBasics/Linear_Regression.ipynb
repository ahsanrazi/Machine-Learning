# %% [markdown]
# # Linear regression Single Variable

# %%
# Linear Regression is the technique which is use to solve Regression Problems.
# In the Regression Problems the predicted values are continuous (Continuous label).

# %%
# Predicting the home prices using Simple Linear Regression.

# %%
# Importing the important Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Reading the File

df = pd.read_csv('Data_Set\\Linear_Regression\\homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# Plotting the Scatter plot to get the idea of the distribution of the data point

# %matplotlib inline

plt.xlabel('area(sqr ft)')
plt.ylabel('price (US$)')
plt.scatter(df['area'], df['price'], color = 'red', marker='+')

# %%
# Creating the Linear Regression Object

reg = linear_model.LinearRegression()

# %%
# Traing the Model using the fit() function

# fit() contain two arguments first argument is 2D array of the independent variable (area)
# second argument is of dependent variable (price)

reg.fit(df[['area']],df['price'])

# df[['area']] -> creating the dataframe using the existing dataframe
# Out:
# LinearRegression()

# %%
# Making Predictions 
# area 3300

reg.predict([[3300]])
# Out:
# c:\Users\Hossnain\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
# Making Predictions 
# area 5000

reg.predict([[5000]])
# Out:
# c:\Users\Hossnain\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
# y = mx + b

# printing the value of m (coefficient)

reg.coef_
# Out:
# array([135.78767123])

# %%
# y = mx + b

# printing the value of b (intercept)

reg.intercept_
# Out:
# 180616.43835616432

# %%
# Plotting the Line

# %matplotlib inline

plt.xlabel('area(sqr ft)')
plt.ylabel('price (US$)')
plt.scatter(df['area'], df['price'], color = 'red', marker='+')
plt.plot(df['area'],reg.predict(df[['area']]), color = 'blue')

# %%
# Predicting prices of the areas in the CSV file 

d = pd.read_csv('Data_Set\\Linear_Regression\\areas.csv')
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
# Making Prediction of CSV

p = reg.predict(d)

# %%
# Creating new column in the dataframe

d['price'] = p

# %%
d
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
# Making new file and export the predictions in it

d.to_csv('Data_Set\\Linear_Regression\\prediction.csv', index=False)

# %%
pred_df = pd.read_csv('Data_Set\\Linear_Regression\\prediction.csv')
pred_df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06
